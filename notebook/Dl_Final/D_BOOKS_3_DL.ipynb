# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\SIDHARTH\Downloads\Main project\books 3.csv')
df.head(5)
# Out:
#    Unnamed: 0          Id                               Title  \
# 0           0  0671551345  Night World: Daughters Of Darkness
# 1           1  0671551345  Night World: Daughters Of Darkness
# 2           2  0671551345  Night World: Daughters Of Darkness
# 3           3  0671551345  Night World: Daughters Of Darkness
# 4           4  0671551345  Night World: Daughters Of Darkness
#
#    review/helpfulness  review/score                         review/summary  \
# 0                1.00             5      This book is one of my favorates.
# 1                1.00             5    My favorite of all her books!!!!!!!
# 2                0.75             5  Second Book in the Night World Series
# 3                0.70             5              This book had me giggling
# 4                1.00             5  One of the best books I've ever read!
#
#                                          review/text  \
# 0  I have read just about everything L.J. Smith h...
# 1  This is the best book L.J. has written, and I'...
# 2  Set in Briar Creek, Oregon, "Daughters of Dark...
# 3  I'm sorry, but I just find the way Mary Lennet...
# 4  DAUGHTERS OF DARKNESS was the first book by L....
#
#                                          description         authors  \
# 0  "There’s something strange about the new girls...  ['L.J. Smith']
# 1  "There’s something strange about the new girls...  ['L.J. Smith']
# 2  "There’s something strange about the new girls...  ['L.J. Smith']
# 3  "There’s something strange about the new girls...  ['L.J. Smith']
# 4  "There’s something strange about the new girls...  ['L.J. Smith']
#
#             publisher        categories  ratingsCount
# 0  Simon and Schuster  Juvenile Fiction            11
# 1  Simon and Schuster  Juvenile Fiction            11
# 2  Simon and Schuster  Juvenile Fiction            11
# 3  Simon and Schuster  Juvenile Fiction            11
# 4  Simon and Schuster  Juvenile Fiction            11

# %%
df.tail(5)
# Out:
#         Unnamed: 0          Id  \
# 278272      474669  B000HOMU4S
# 278273      474670  B000HOMU4S
# 278274      474671  B000HOMU4S
# 278275      474672  B000HOMU4S
# 278276      474673  B000HOMU4S
#
#                                                     Title  review/helpfulness  \
# 278272  The Fall of Freddie the Leaf: 20th Aniversary ...            0.916667
# 278273  The Fall of Freddie the Leaf: 20th Aniversary ...            0.947368
# 278274  The Fall of Freddie the Leaf: 20th Aniversary ...            1.000000
# 278275  The Fall of Freddie the Leaf: 20th Aniversary ...            1.000000
# 278276  The Fall of Freddie the Leaf: 20th Aniversary ...            1.000000
#
#         review/score                                     review/summary  \
# 278272             5                                  Highly recommend.
# 278273             5  One of the few books that stands out about my ...
# 278274             5                    A must have for every household
# 278275             5     Superb book for explaining a substantial loss!
# 278276             5                                            Healing
#
#                                               review/text  \
# 278272  I believe that The Fall of Freddie the Leaf is...
# 278273  This book stands out above any other book I ev...
# 278274  This book is so eloquent and profound, you may...
# 278275  This book was given to my brother and I when o...
# 278276  This book touches the heart and fills you with...
#
#                                               description  \
# 278272  As Freddie experiences the changing seasons al...
# 278273  As Freddie experiences the changing seasons al...
# 278274  As Freddie experiences the changing seasons al...
# 278275  As Freddie experiences the changing seasons al...
# 278276  As Freddie experiences the changing seasons al...
#
#                      authors             publisher categories  ratingsCount
# 278272  ['Leo F. Buscaglia']  Henry Holt & Company  Self-Help             8
# 278273  ['Leo F. Buscaglia']  Henry Holt & Company  Self-Help             8
# 278274  ['Leo F. Buscaglia']  Henry Holt & Company  Self-Help             8
# 278275  ['Leo F. Buscaglia']  Henry Holt & Company  Self-Help             8
# 278276  ['Leo F. Buscaglia']  Henry Holt & Company  Self-Help             8

# %%
df.shape
# Out:
# (278277, 12)

# %%
df.sample(5)
# Out:
#         Unnamed: 0          Id  \
# 249243      420315  B00097DWY0
# 96240       154250  1573220876
# 56134        89229  0451125819
# 241392      406499  0785731261
# 87134       139577  0739326732
#
#                                                     Title  review/helpfulness  \
# 249243      Blink: The Power of Thinking Without Thinking            1.000000
# 96240                                         About a Boy            1.000000
# 56134                                       We the Living            0.800000
# 241392  Case Closed: Lee Harvey Oswald and the Assassi...            0.833333
# 87134   The Innocent Man: Murder and Injustice in a Sm...            1.000000
#
#         review/score                                  review/summary  \
# 249243             5  Why and how split-second decisions are made...
# 96240              4                                 Very good read!
# 56134              5           The most honest of Ayn Rand's novels.
# 241392             3                Good biography; poor critique...
# 87134              5                Very different for John Grisham.
#
#                                               review/text  \
# 249243  I finally got around to reading a book that's ...
# 96240   I really enjoyed this book. It was a very fast...
# 56134   Whether you agree with her philosophy or not, ...
# 241392  On November 22, 1963, a deranged Lee Harvey Os...
# 87134   This book was not what I expected as a huge Jo...
#
#                                               description  \
# 249243  From the #1 bestselling author of The Bomber M...
# 96240   Nick Hornby's second bestselling novel is abou...
# 56134   We the Living depicts the struggle of the indi...
# 241392  Pulitzer Prize Finalist: “By far the most luci...
# 87134   Presents the real-life case of Ron Williamson,...
#
#                      authors                publisher            categories  \
# 249243  ['Malcolm Gladwell']           Back Bay Books  Business & Economics
# 96240        ['Nick Hornby']               Penguin UK               Fiction
# 56134           ['Ayn Rand']                   Signet               Fiction
# 241392     ['Gerald Posner']          Open Road Media               History
# 87134       ['John Grisham']  Dell Publishing Company        Social Science
#
#         ratingsCount
# 249243          3948
# 96240             66
# 56134             17
# 241392            15
# 87134             82

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278277 entries, 0 to 278276
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Unnamed: 0          278277 non-null  int64
#  1   Id                  278277 non-null  object
#  2   Title               278277 non-null  object
#  3   review/helpfulness  278277 non-null  float64
#  4   review/score        278277 non-null  int64
#  5   review/summary      278277 non-null  object
#  6   review/text         278277 non-null  object
#  7   description         278277 non-null  object
#  8   authors             278277 non-null  object
#  9   publisher           278277 non-null  object
#  10  categories          278277 non-null  object
#  11  ratingsCount        278277 non-null  int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 25.5+ MB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Id', 'Title', 'review/helpfulness', 'review/score',
#        'review/summary', 'review/text', 'description', 'authors', 'publisher',
#        'categories', 'ratingsCount'],
#       dtype='object')

# %% [markdown]
# Rating Distribution

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['review/score'], bins=5)
plt.title("📈 Rating Distribution")
plt.xlabel("Review Score")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\SIDHARTH\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Word Clouds for High vs. Low Ratings

# %%
from wordcloud import WordCloud

high_reviews = df[df['review/score'] >= 4]['review/text'].dropna()
low_reviews = df[df['review/score'] <= 2]['review/text'].dropna()

WordCloud(width=800, height=400).generate(" ".join(high_reviews))
WordCloud(width=800, height=400).generate(" ".join(low_reviews))

# %% [markdown]
# Sentiment vs. Rating Consistency

# %%
from textblob import TextBlob

df['sentiment'] = df['review/text'].fillna('').apply(lambda x: TextBlob(x).sentiment.polarity)

sns.scatterplot(data=df, x='sentiment', y='review/score', alpha=0.3)
plt.title("🧠 Sentiment vs. Rating")
plt.xlabel("Sentiment Polarity")
plt.ylabel("Review Score")
plt.show()
# Out:
# C:\Users\SIDHARTH\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 129504 (\N{BRAIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Review Length vs. Rating

# %%
df['length'] = df['review/text'].fillna('').apply(lambda x: len(x.split()))

sns.boxplot(data=df, x='review/score', y='length')
plt.title("📝 Review Length vs. Rating")
plt.xlabel("Rating")
plt.ylabel("Review Length (words)")
plt.show()
# Out:
# C:\Users\SIDHARTH\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128221 (\N{MEMO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Helpfulness vs. Rating

# %%
pip install boxplot
# Out:
# Requirement already satisfied: boxplot in c:\users\sidharth\appdata\local\programs\python\python313\lib\site-packages (0.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
sns.boxplot(data=df, x='review/score', y='review/helpfulness')
plt.title("👍 Helpfulness vs. Rating")
plt.xlabel("Rating")
plt.ylabel("Helpfulness Score")
plt.yscale('log')  # Optional for skewed values
plt.show()
# Out:
# C:\Users\SIDHARTH\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128077 (\N{THUMBS UP SIGN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Category-Level Rating Trends

# %%
category_avg = df.groupby('categories')['review/score'].mean().sort_values()
category_avg.plot(kind='barh', figsize=(10, 30), title="📚 Avg Rating by Category")
plt.xlabel("Average Score")
plt.show()
# Out:
# C:\Users\SIDHARTH\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128218 (\N{BOOKS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df.drop(columns=['Unnamed: 0', 'Id', 'Title', 'review/helpfulness',
       'review/summary', 'description', 'authors', 'publisher',
       'categories', 'ratingsCount'],inplace=True)

# %%
df.columns
# Out:
# Index(['review/score', 'review/text', 'sentiment', 'length'], dtype='object')

# %%
df.isnull().sum()
# Out:
# review/score    0
# review/text     0
# sentiment       0
# length          0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.rename(columns={'review/text':'review','review/score':'rating'},inplace=True)

# %%
df.head(5)
# Out:
#    rating                                             review  sentiment  \
# 0       5  I have read just about everything L.J. Smith h...   0.324349
# 1       5  This is the best book L.J. has written, and I'...   0.408333
# 2       5  Set in Briar Creek, Oregon, "Daughters of Dark...   0.080278
# 3       5  I'm sorry, but I just find the way Mary Lennet...   0.142763
# 4       5  DAUGHTERS OF DARKNESS was the first book by L....   0.326563
#
#    length
# 0     170
# 1      84
# 2     233
# 3     205
# 4      82

# %%
print(df.duplicated().sum())
# Out:
# 95360

# %%
df.drop_duplicates(subset=['review','rating'],inplace=True)

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
import re

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r"[^\w\s]", "", text)
    text = re.sub(r"\d+", "", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

df.loc[:, "review"] = df["review"].apply(clean_text)

# %%
df['rating']=df['rating'].astype(int)

# %%
df['rating'].value_counts()
# Out:
# rating
# 5    113817
# 4     34927
# 3     13895
# 1     11220
# 2      9058
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (182917, 4)

# %%
df.sample(5)
# Out:
#         rating                                             review  sentiment  \
# 73913        4  who would think bernard malamud could capture ...   0.135714
# 198049       5  this is my favorite book out of tlotr in my op...   0.217980
# 82086        5  its one of the best military history books ive...   0.237500
# 28482        2  i have been a loyal reader of this series but ...   0.052818
# 136787       5  as a somewhat new mom months i can fully appre...   0.040427
#
#         length
# 73913       63
# 198049     105
# 82086       87
# 28482      109
# 136787     129

# %%
df.to_csv('D-BOOKS - 3 DL.csv',index=False)
