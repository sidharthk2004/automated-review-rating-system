# %%
import pandas as pd
df=pd.read_csv('/content/switch-games.csv')
df.head(5)
# Out:
#          id                                             title  \
# 0  0f0191a3                            The DioField Chronicle
# 1  f2af5f5f            The Legend of Heroes: Trails from Zero
# 2  a8996117                                          NBA 2K23
# 3  e2f10932                                            Temtem
# 4  51ff4f64  Made in Abyss: Binary Star Falling into Darkness
#
#                                             game_url  \
# 0  https://www.nintendolife.com/reviews/nintendo-...
# 1  https://www.nintendolife.com/reviews/nintendo-...
# 2  https://www.nintendolife.com/reviews/nintendo-...
# 3  https://www.nintendolife.com/reviews/nintendo-...
# 4  https://www.nintendolife.com/reviews/nintendo-...
#
#                                            image_url           system  \
# 0  https://images.nintendolife.com/d9a6ef84ec8cf/...  Nintendo Switch
# 1  https://images.nintendolife.com/004c2655b08cc/...  Nintendo Switch
# 2  https://images.nintendolife.com/60aff0dbdc402/...  Nintendo Switch
# 3  https://images.nintendolife.com/c6c585ce49b59/...  Nintendo Switch
# 4  https://images.nintendolife.com/063177f5b67f4/...  Nintendo Switch
#
#            publisher        developer                      genre  \
# 0        Square Enix      Square Enix  RPG  Simulation  Strategy
# 1        NIS America     Nihon Falcom                        RPG
# 2                 2K  Visual Concepts                     Sports
# 3       Humble Games      Crema Games     Action  Adventure  RPG
# 4  Spike Chunsoft US            Chime                Action  RPG
#
#       num_players   release_date  \
# 0               1  22nd Sep 2022
# 1               1  27th Sep 2022
# 2   4 (10 Online)   9th Sep 2022
# 3  1 (999 Online)   6th Sep 2022
# 4               1   2nd Sep 2022
#
#                                               review  \
# 0  Published by Square Enix and developed with as...
# 1  We dont blame you if you’re intimidated by Fal...
# 2  Its once again reached that time of year when ...
# 3  At the beginning of our Temtem adventure  we h...
# 4  Made in Abyss feels like an anime/manga ripe f...
#
#                                    review_conclusion num_votes  rating
# 0  Despite its shortcomings  The DioField Chronic...         0     0.0
# 1  In a series renowned for its stellar writing  ...         0     0.0
# 2  NBA 2K23 makes the inevitable downgrades and c...         2     0.0
# 3  Even without the endgame content  Temtem is wo...         5     7.8
# 4  Made in Abyss is an odd game to recommend; the...         2     0.0

# %%
df.tail(5)
# Out:
#            id                                    title  \
# 632  0f933f58                   Skylanders Imaginators
# 633  44b24a40                          Just Dance 2017
# 634  1e8edaf2                        Super Bomberman R
# 635  92d53aa6                               1-2-Switch
# 636  97fc82c2  The Legend of Zelda: Breath of the Wild
#
#                                               game_url  \
# 632  https://www.nintendolife.com/reviews/nintendo-...
# 633  https://www.nintendolife.com/reviews/nintendo-...
# 634  https://www.nintendolife.com/reviews/nintendo-...
# 635  https://www.nintendolife.com/reviews/nintendo-...
# 636  https://www.nintendolife.com/reviews/nintendo-...
#
#                                              image_url           system  \
# 632  https://images.nintendolife.com/83212dea254b0/...  Nintendo Switch
# 633  https://images.nintendolife.com/1eafb4d828558/...  Nintendo Switch
# 634  https://images.nintendolife.com/cfd86c7a10b1b/...  Nintendo Switch
# 635  https://images.nintendolife.com/dc982b88045e5/...  Nintendo Switch
# 636  https://images.nintendolife.com/e409aebf4d1f2/...  Nintendo Switch
#
#       publisher     developer              genre num_players  release_date  \
# 632  Activision  Toys for Bob  Action  Adventure           2  3rd Mar 2017
# 633     Ubisoft       Ubisoft     Dancing  Music           6  3rd Mar 2017
# 634      Konami        Konami     Action  Puzzle           8  3rd Mar 2017
# 635    Nintendo      Nintendo              Party           2  3rd Mar 2017
# 636    Nintendo  Nintendo SPD  Action  Adventure           1  3rd Mar 2017
#
#                                                 review  \
# 632  Skylanders Imaginators may be a launch title o...
# 633  People all over the world have finally got the...
# 634  When most people pick up their Switch  theyll ...
# 635  Would the Wii have sold over 100 million units...
# 636  The Legend of Zelda has always been a franchis...
#
#                                      review_conclusion num_votes  rating
# 632  If you are looking for a family-friendly way t...        21     7.4
# 633  Just Dance 2017 is great at what it does – ser...        25     7.1
# 634  Super Bomberman R is a no-frills entry in a se...       205     6.8
# 635  1-2-Switch does a great job of showing off the...       175     5.9
# 636  The Legend of Zelda: Breath of the Wild is a l...     2 782     9.6

# %%
df.sample(5)
# Out:
#            id                    title  \
# 58   591b470a  Pokémon Legends: Arceus
# 219  264cb871      Nexomon: Extinction
# 622  d949d47b    Cars 3: Driven to Win
# 560  c9967a29    Dragon Quest Builders
# 297  04bde0b0  Bubble Bobble 4 Friends
#
#                                               game_url  \
# 58   https://www.nintendolife.com/reviews/nintendo-...
# 219  https://www.nintendolife.com/reviews/nintendo-...
# 622  https://www.nintendolife.com/reviews/nintendo-...
# 560  https://www.nintendolife.com/reviews/nintendo-...
# 297  https://www.nintendolife.com/reviews/nintendo-...
#
#                                              image_url           system  \
# 58   https://images.nintendolife.com/30e83bd615fbf/...  Nintendo Switch
# 219  https://images.nintendolife.com/8cc63be8c5fab/...  Nintendo Switch
# 622  https://images.nintendolife.com/cfc9f6aa98e8f/...  Nintendo Switch
# 560  https://images.nintendolife.com/e90ca21dac06b/...  Nintendo Switch
# 297  https://images.nintendolife.com/d96fb15df24e7/...  Nintendo Switch
#
#                     publisher           developer                   genre  \
# 58                   Nintendo          Game Freak             Action  RPG
# 219                     PQube    VEWO Interactive          Adventure  RPG
# 622  Warner Bros. Interactive  Avalanche Software                  Racing
# 560                  Nintendo         Square Enix  Action  Adventure  RPG
# 297                ININ Games               Taito   Action  Arcade  Party
#
#     num_players   release_date  \
# 58            2  28th Jan 2022
# 219           1  28th Aug 2020
# 622           4  13th Jun 2017
# 560           1   9th Feb 2018
# 297           4           2020
#
#                                                 review  \
# 58   A century before it became the land of Sinnoh ...
# 219  Lets get one thing straight before we begin: w...
# 622  Nintendo systems often get tie-ins for popular...
# 560  Having spent plenty of time questing  building...
# 297  Since the release of the original arcade class...
#
#                                      review_conclusion num_votes  rating
# 58   Pokémon Legends: Arceus feels like the result ...       209     8.7
# 219  Nexomon: Extinction does enough to make it som...        49     7.1
# 622  Cars 3: Driven to Win falls for some of the pi...        15     6.1
# 560  Both classic Dragon Quest RPG and Minecraft-st...       126     7.9
# 297  Bubble Bobble 4 Friends is a great modern addi...        27     7.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 637 entries, 0 to 636
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 637 non-null    object
#  1   title              637 non-null    object
#  2   game_url           637 non-null    object
#  3   image_url          637 non-null    object
#  4   system             637 non-null    object
#  5   publisher          631 non-null    object
#  6   developer          627 non-null    object
#  7   genre              622 non-null    object
#  8   num_players        612 non-null    object
#  9   release_date       637 non-null    object
#  10  review             637 non-null    object
#  11  review_conclusion  627 non-null    object
#  12  num_votes          637 non-null    object
#  13  rating             637 non-null    float64
# dtypes: float64(1), object(13)
# memory usage: 69.8+ KB

# %%
df.describe()
# Out:
#            rating
# count  637.000000
# mean     6.385243
# std      2.257483
# min      0.000000
# 25%      6.000000
# 50%      7.200000
# 75%      7.800000
# max      9.600000

# %%
df.columns
# Out:
# Index(['id', 'title', 'game_url', 'image_url', 'system', 'publisher',
#        'developer', 'genre', 'num_players', 'release_date', 'review',
#        'review_conclusion', 'num_votes', 'rating'],
#       dtype='object')

# %%
df.drop(columns=['id', 'title', 'game_url', 'image_url', 'system', 'publisher',
       'developer', 'genre', 'num_players', 'release_date', 'review', 'num_votes'],inplace=True)

# %%
df.isnull().sum() #to identify how much null values are there
# Out:
# id                    0
# title                 0
# game_url              0
# image_url             0
# system                0
# publisher             6
# developer            10
# genre                15
# num_players          25
# release_date          0
# review                0
# review_conclusion    10
# num_votes             0
# rating                0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.rename(columns={'review_conclusion':'REVIEW'},inplace=True)

# %%
df.head(5)
# Out:
#          id                                             title  \
# 0  0f0191a3                            The DioField Chronicle
# 1  f2af5f5f            The Legend of Heroes: Trails from Zero
# 2  a8996117                                          NBA 2K23
# 3  e2f10932                                            Temtem
# 4  51ff4f64  Made in Abyss: Binary Star Falling into Darkness
#
#                                             game_url  \
# 0  https://www.nintendolife.com/reviews/nintendo-...
# 1  https://www.nintendolife.com/reviews/nintendo-...
# 2  https://www.nintendolife.com/reviews/nintendo-...
# 3  https://www.nintendolife.com/reviews/nintendo-...
# 4  https://www.nintendolife.com/reviews/nintendo-...
#
#                                            image_url           system  \
# 0  https://images.nintendolife.com/d9a6ef84ec8cf/...  Nintendo Switch
# 1  https://images.nintendolife.com/004c2655b08cc/...  Nintendo Switch
# 2  https://images.nintendolife.com/60aff0dbdc402/...  Nintendo Switch
# 3  https://images.nintendolife.com/c6c585ce49b59/...  Nintendo Switch
# 4  https://images.nintendolife.com/063177f5b67f4/...  Nintendo Switch
#
#            publisher        developer                      genre  \
# 0        Square Enix      Square Enix  RPG  Simulation  Strategy
# 1        NIS America     Nihon Falcom                        RPG
# 2                 2K  Visual Concepts                     Sports
# 3       Humble Games      Crema Games     Action  Adventure  RPG
# 4  Spike Chunsoft US            Chime                Action  RPG
#
#       num_players   release_date  \
# 0               1  22nd Sep 2022
# 1               1  27th Sep 2022
# 2   4 (10 Online)   9th Sep 2022
# 3  1 (999 Online)   6th Sep 2022
# 4               1   2nd Sep 2022
#
#                                               review  \
# 0  Published by Square Enix and developed with as...
# 1  We dont blame you if you’re intimidated by Fal...
# 2  Its once again reached that time of year when ...
# 3  At the beginning of our Temtem adventure  we h...
# 4  Made in Abyss feels like an anime/manga ripe f...
#
#                                               REVIEW num_votes  rating
# 0  Despite its shortcomings  The DioField Chronic...         0     0.0
# 1  In a series renowned for its stellar writing  ...         0     0.0
# 2  NBA 2K23 makes the inevitable downgrades and c...         2     0.0
# 3  Even without the endgame content  Temtem is wo...         5     7.8
# 4  Made in Abyss is an odd game to recommend; the...         2     0.0

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.drop_duplicates(subset=['REVIEW','rating'],inplace=True)

# %%
import re

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r"[^\w\s]", "", text)
    text = re.sub(r"\d+", "", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

df.loc[:, "REVIEW"] = df["REVIEW"].apply(clean_text)

# %% [markdown]
# COLUMNS UPDATE TO INT

# %%
df['rating']=df['rating'].astype(int)

# %%
df['rating'].value_counts()
# Out:
# rating
# 7    267
# 6    111
# 8     68
# 5     49
# 0     35
# 4     30
# 9     15
# 2     10
# 3      9
# Name: count, dtype: int64

# %%
df=df[df['rating']!=0]

# %%
df['rating'].value_counts()
# Out:
# rating
# 3    378
# 4     83
# 2     79
# 1     19
# Name: count, dtype: int64

# %%
df['rating']=df['rating']/2

# %%
df['rating']=df['rating'].astype(int)

# %%
df.shape
# Out:
# (559, 14)

# %%
df.to_csv('clean_game.csv',index=False)
