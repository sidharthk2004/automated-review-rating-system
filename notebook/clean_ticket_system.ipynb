# %%
import pandas as pd
df=pd.read_csv('/content/capterra_reviews.csv')
df.head(5)
# Out:
#   ticket_system                                              title  \
# 0     Zoho Desk  Excellent solution that meets all of our requi...
# 1     Zoho Desk  Offers multiple options to help customers get ...
# 2     Zoho Desk  Zoho Desk isn't a favourite option of mine, bu...
# 3     Zoho Desk                          Keep your customers happy
# 4     Zoho Desk    A fantastic tool for answering customer queries
#
#                                         overall_text  \
# 0  Zoho Desk is a top-tier platform for developin...
# 1  Provides web-based customer support, reducing ...
# 2  Zoho Desk is a great tool with many features, ...
# 3  Zoho Desk is very responsive and fast, is pack...
# 4  Questions about orders or invoices, tickets, a...
#
#                                            pros_text  \
# 0  As a ticketing and customer service platform, ...
# 1  In the period I have used Zoho Desk, I have ex...
# 2  Zoho Desk offers a range of tools to make sure...
# ...

# %%
df.tail(5)
# Out:
#      ticket_system                                         title  \
# 4894          otrs             Easy tracking of reported queries
# 4895          otrs                A tool for processing requests
# 4896          otrs  The best open sourcebest practice's software
# 4897          otrs                   great tool for our business
# 4898          otrs                 Great way for IT organization
#
#                                            overall_text  \
# 4894  Pros:user friendly and easy to use. enables es...
# 4895  Pros:You can organize tickets in categories an...
# 4896  Pros:The best open sourcebest practice's softw...
# 4897  Pros:very easy to use and fast interface that ...
# 4898  Pros:Our IT department utilizes OTRS as a plat...
#
#                                               pros_text  \
# 4894  Cons:users are copied with emails the replied ...
# 4895  Cons:Difficult to install and configure, getti...
# 4896  Vendor ResponseBy OTRS on June 3, 2016Thank yo...
# ...

# %%
df.sample(5)
# Out:
#                 ticket_system                                 title  \
# 4082               ServiceNow             Logiciel de Support agent
# 63                  Zoho Desk       Full-Featured Business Software
# 4666  Jira Service Management                        Review as user
# 1744                Freshdesk  Strong software for customer support
# 2567                  Zendesk         Professionalism with Zendesk.
#
#                                            overall_text  \
# 4082  Pros:ServiceNow est le meilleur produit de ges...
# 63    By delivering a plethora of applications in on...
# 4666  Pros:Efficiency in managing service requests a...
# 1744  Pros:- Quite tailored to the German market- Ma...
# 2567  One of the standout features of Zendesk Suite ...
#
#                                               pros_text  \
# 4082  Cons:Un super produit mais je souhaite l'améli...
# 63    With Zoho One, organizations get access to a s...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4899 entries, 0 to 4898
# Data columns (total 21 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   ticket_system                               4899 non-null   object
#  1   title                                       4852 non-null   object
#  2   overall_text                                4852 non-null   object
#  3   pros_text                                   4790 non-null   object
#  4   cons_text                                   3232 non-null   object
#  5   overall_rating                              4899 non-null   int64
#  6   ease_of_use                                 4865 non-null   float64
#  7   customer_service                            4037 non-null   float64
#  8   features                                    4818 non-null   float64
# ...

# %%
df.describe()
# Out:
#        overall_rating  ease_of_use  customer_service     features  \
# count     4899.000000  4865.000000       4037.000000  4818.000000
# mean         4.512349     4.376978          4.335150     4.400789
# std          0.697953     0.812705          0.943858     0.759286
# min          1.000000     1.000000          1.000000     1.000000
# 25%          4.000000     4.000000          4.000000     4.000000
# 50%          5.000000     5.000000          5.000000     5.000000
# 75%          5.000000     5.000000          5.000000     5.000000
# max          5.000000     5.000000          5.000000     5.000000
#
#        value_for_money  likelihood_to_recommend  \
# count      3975.000000              4546.000000
# mean          4.361258                 8.562692
# std           0.864969                 1.526490
# min           1.000000                 1.000000
# 25%           4.000000                 8.000000
# 50%           5.000000                 9.000000
# ...

# %%
df.columns
# Out:
# Index(['ticket_system', 'title', 'overall_text', 'pros_text', 'cons_text',
#        'overall_rating', 'ease_of_use', 'customer_service', 'features',
#        'value_for_money', 'likelihood_to_recommend',
#        'Ticket Creation and Assignment', 'Automated Ticket Routing',
#        'Status Tracking and Updates', 'Priority and SLA Management',
#        'Customer and Agent Portals', 'Knowledge Base Integration',
#        'Email Notifications and Alerts', 'Reporting and Analytics',
#        'Customizable Workflows', 'Multi-Channel Support (Email, Chat, Phone)'],
#       dtype='object')

# %%
df.drop(columns=['ticket_system', 'title', 'pros_text', 'cons_text',
        'ease_of_use', 'customer_service', 'features',
       'value_for_money', 'likelihood_to_recommend',
       'Ticket Creation and Assignment', 'Automated Ticket Routing',
       'Status Tracking and Updates', 'Priority and SLA Management',
       'Customer and Agent Portals', 'Knowledge Base Integration',
       'Email Notifications and Alerts', 'Reporting and Analytics',
       'Customizable Workflows', 'Multi-Channel Support (Email, Chat, Phone)'],inplace=True)

# %%
df.isnull().sum()# to identify how much null values are there
# Out:
# overall_text      0
# overall_rating    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.rename(columns={'overall_text':'review','overall_rating':'rating'},inplace=True)

# %%
df.head(5)
# Out:
#                                               review  rating
# 0  Zoho Desk is a top-tier platform for developin...       5
# 1  Provides web-based customer support, reducing ...       5
# 2  Zoho Desk is a great tool with many features, ...       3
# 3  Zoho Desk is very responsive and fast, is pack...       5
# 4  Questions about orders or invoices, tickets, a...       4

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.drop_duplicates(subset=['review','rating'],inplace=True)

# %%
import re

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r"[^\w\s]", "", text)
    text = re.sub(r"\d+", "", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

df.loc[:, "review"] = df["review"].apply(clean_text)

# %% [markdown]
# COLUMNS UPDATE TO INT

# %%
df['rating']=df['rating'].astype(int)

# %%
df['rating'].value_counts()
# Out:
# rating
# 5    2917
# 4    1606
# 3     240
# 2      45
# 1      32
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (4840, 2)

# %%
df.to_csv('clean_ticket_system.csv',index=False)
