# %%
import pandas as pd
df = pd.read_csv('/content/clean_chatgpt_reviews.csv')
df.head(5)
# Out:
#    Unnamed: 0                 userName  \
# 0           0          T H (Trudylh20)
# 1           1     Muhammad bassam adam
# 2           2            Chinaza Okoli
# 3           3  Project House Group Ltd
# 4           4             Safoan Riyad
#
#                                              content  score  thumbsUpCount  \
# 0                         excellent Im impressed 👌 👏      5              0
# 1                                            perfect      5              0
# 2                      its been so helpful...love it      5              0
# 3     It's amazing tools help me a lot with my work.      5              0
# 4  I enjoyed ChatGPT. But last update ruined ever...      1              0
#
#                  at
# 0  28-06-2024 21:07
# 1  28-06-2024 20:56
# 2  28-06-2024 20:54
# 3  28-06-2024 20:51
# 4  28-06-2024 20:50

# %%
df.tail(5)
# Out:
#         Unnamed: 0           userName             content  score  \
# 149714      149720   m.santhosh Kumar         Update 2023      5
# 149715      149721   Andrew Bourgeois           its grear      5
# 149716      149722           Dern Bob       Funtastic App      5
# 149717      149723  Abdur rahman arif              hi all      5
# 149718      149724       Tushar Deran  expert application      5
#
#         thumbsUpCount                at
# 149714              0  27-07-2023 16:26
# 149715              0  23-09-2023 16:25
# 149716              0  08-11-2023 13:57
# 149717              0  25-07-2023 15:32
# 149718              0  30-11-2023 18:11

# %%
df.sample(5)
# Out:
#         Unnamed: 0                userName  \
# 137448      137454  16 - Devesh Chaturbhuj
# 14978        14979               HEIN HTET
# 57803        57804                 Prantik
# 60697        60698              King Kumar
# 4716          4717       PRASUN KUMAR KHAN
#
#                                                   content  score  \
# 137448                                                 Ok      4
# 14978                                                good      5
# 57803   it is a great app . I am really satisfied with...      5
# 60697                                       very nice app      5
# 4716                                         disappointed      1
#
#         thumbsUpCount                at
# 137448              0  09-11-2023 15:58
# 14978               0  03-06-2024 05:57
# 57803               0  22-04-2024 14:56
# 60697               0  05-05-2024 18:45
# 4716                0  18-06-2024 18:46

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149719 entries, 0 to 149718
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     149719 non-null  int64
#  1   userName       149719 non-null  object
#  2   content        149719 non-null  object
#  3   score          149719 non-null  int64
#  4   thumbsUpCount  149719 non-null  int64
#  5   at             149719 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 6.9+ MB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'userName', 'content', 'score', 'thumbsUpCount', 'at'], dtype='object')

# %%
df.drop(columns=['Unnamed: 0', 'userName', 'thumbsUpCount', 'at'],inplace=True)

# %%
df.isnull().sum() #to identify how much null values are there
# Out:
# content    0
# score      0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.rename(columns={'content':'review','score':'rating'},inplace=True)

# %%
df.head(5)
# Out:
#                                               review  rating
# 0                             excellent im impressed       5
# 1                                            perfect       5
# 2                         its been so helpfullove it       5
# 3       its amazing tools help me a lot with my work       5
# 4  i enjoyed chatgpt but last update ruined every...       1

# %%
print(df.duplicated().sum())
# Out:
# 48394

# %%
df.drop_duplicates(subset=['review','rating'],inplace=True)

# %%
import re

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r"[^\w\s]", "", text)
    text = re.sub(r"\d+", "", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

df.loc[:, "review"] = df["review"].apply(clean_text)

# %% [markdown]
# COLUMNS UPDATE TO INT

# %%
df['rating']=df['rating'].astype(int)

# %%
df['rating'].value_counts()
# Out:
# rating
# 5    72127
# 4    13195
# 1     8532
# 3     5110
# 2     2361
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (101325, 2)

# %%
df.to_csv('clean_chatgpt.csv',index=False)
