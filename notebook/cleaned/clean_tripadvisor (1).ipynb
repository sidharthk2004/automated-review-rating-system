# %%
import pandas as pd
df=pd.read_csv('/content/JAL_tripadvisor_reviews.csv')
df.head(5)
# Out:
#                                                title  \
# 0  Pleasant Flights For Senior Passengers From Ja...
# 1            Dunno why people recommend this airline
# 2                          BEST 5 HOURS FLIGHT EVER!
# 3                     Nice Flight...Terrible Website
# 4  Great Legroom, Best Flight Experience, On Sche...
#
#                                                 text lang published_date  \
# 0  My elderly father, my aunt (  my late mother’s...   en     2024-11-05
# 1  Dunno how people rate this airline as good, ea...   en     2024-10-21
# 2  I flew Japan Airlines From Bangkok to Osaka, a...   en     2024-10-20
# 3  In a way JAL reminds me of my entire Japan exp...   en     2024-10-19
# 4  Great, maybe BEST flight experience. Always on...   en     2024-10-18
#
#   travel_date  helpful_votes  rating
# 0  2024-05-31              0       4
# 1  2024-10-31              0       1
# 2  2024-10-31              2       5
# 3  2023-12-31              1       5
# ...

# %%
df.tail(5)
# Out:
#                                     title  \
# 9559                           Impressive
# 9560  Excellent Service on all flights!!!
# 9561                       The Rising Sun
# 9562                             Just wow
# 9563                        Great service
#
#                                                    text lang published_date  \
# 9559  I accidentally got a great ticket deal from Ex...   en     2016-01-27
# 9560  It was my first time with this airline and my ...   en     2016-01-27
# 9561  After a long layover while I tried to sleep in...   en     2016-01-26
# 9562  The best airline and service ive seen in a lon...   en     2016-01-26
# 9563  Service on board was fantastic. flight attenda...   en     2016-01-25
#
#      travel_date  helpful_votes  rating
# 9559  2016-01-31              3       5
# 9560  2016-01-31              1       5
# 9561  2016-01-31              1       5
# 9562  2015-03-31              2       5
# 9563  2016-01-31              1       4

# %%
df.sample()
# Out:
#                                            title  \
# 3841  Superior service from Japan's flag carrier
#
#                                                    text lang published_date  \
# 3841  Due to some inexplicable snafu, we weren't abl...   en     2018-09-25
#
#      travel_date  helpful_votes  rating
# 3841  2018-09-30              1       5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3177 entries, 0 to 9563
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3177 non-null   object
#  1   text            3177 non-null   object
#  2   lang            3177 non-null   object
#  3   published_date  3177 non-null   object
#  4   travel_date     3065 non-null   object
#  5   helpful_votes   3177 non-null   int64
#  6   rating          3177 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 198.6+ KB

# %%
df.describe()
# Out:
#        helpful_votes       rating
# count    3177.000000  3177.000000
# mean        1.103872     4.177211
# std         2.026099     1.233867
# min         0.000000     1.000000
# 25%         0.000000     4.000000
# 50%         1.000000     5.000000
# 75%         2.000000     5.000000
# max        56.000000     5.000000

# %%
df = df[df["lang"] == "en"]

# %%
df.columns
# Out:
# Index(['title', 'text', 'lang', 'published_date', 'travel_date',
#        'helpful_votes', 'rating'],
#       dtype='object')

# %%
df.drop(columns=['title','lang', 'published_date', 'travel_date',
       'helpful_votes'],inplace=True)

# %%
df.isnull().sum()#to identify how much null values are there
# Out:
# text      0
# rating    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.rename(columns={'text':'review'},inplace=True)

# %%
df.head(2)
# Out:
#                                               review  rating
# 0  My elderly father, my aunt (  my late mother’s...       4
# 1  Dunno how people rate this airline as good, ea...       1

# %%
print(df.duplicated().sum())
# Out:
# 1

# %%
df.drop_duplicates(subset=['review','rating'],inplace=True)

# %%
import re

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r"[^\w\s]", "", text)
    text = re.sub(r"\d+", "", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

df.loc[:, "review"] = df["review"].apply(clean_text)

# %% [markdown]
# COLUMNS UPDATE TO INT

# %%
df['rating']=df['rating'].astype(int)

# %%
df['rating'].value_counts()
# Out:
# rating
# 5    1829
# 4     729
# 1     270
# 3     239
# 2     109
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (3176, 2)

# %%
df.to_csv('clean_tripadvisor.csv',index=False)
