# %%
import pandas as pd
df=pd.read_csv('/content/merge_df.csv')
df.head(5)
# Out:
#                                               review  rating
# 0  looks durable charging is fine toono complains...       4
# 1  i ordered this cable to connect my phone to an...       4
# 2  not quite durable and sturdy good nice product...       3
# 3  good productlong wirecharges goodnicei bought ...       4
# 4  bought this instead of original apple does the...       4

# %%
df.tail(5)
# Out:
#                                                    review  rating
# 185844  best kept secret rd time staying charm not sta...       5
# 185845  great location price view hotel great quick pl...       4
# 185846  ok just looks nice modern outside desk staff n...       2
# 185847  hotel theft ruined vacation hotel opened sept ...       1
# 185848  people talking ca nt believe excellent ratings...       2

# %%
df.sample(5)
# Out:
#                                                    review  rating
# 169251  nt know complain wife just returned punta cana...       5
# 111009  i got on this med because my fluoxetine stoppp...       2
# 49190   this app is really amazing and gives great exp...       4
# 30590   i m very helpful after getting chat gpt as my ...       5
# 61774                                    good in replying       5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185849 entries, 0 to 185848
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   review  184727 non-null  object
#  1   rating  185849 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 2.8+ MB

# %%
df.shape
# Out:
# (185849, 2)

# %%
df.isnull().sum()
# Out:
# review    0
# rating    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.drop_duplicates(subset=['review','rating'],inplace=True)

# %%
df['rating'].value_counts()
# Out:
# rating
# 5    92127
# 4    34759
# 3    16682
# 1    15825
# 2    11493
# Name: count, dtype: int64

# %%
df.sort_values(by='rating',ascending=True,inplace=True)

# %%
df.shape
# Out:
# (170886, 2)

# %%
df.to_csv('merge_datasets.csv',index=False)
